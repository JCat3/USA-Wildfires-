# %% [markdown]
# # Lighting Wildfires

# %% [markdown]
# #### Dependencies

# %%
from config import gkey
import gmaps
import numpy as np
import pandas as pd
import requests
import time
from scipy.stats import linregress
from matplotlib import pyplot as plt

# %% [markdown]
# ## Create DataFrame from csv
# Selecting perferred column to speed up compute time

# %%
# Raw Data
raw_data = pd.read_csv("./Wildfire Data/FW_Veg_Rem_Combined.csv")
print(raw_data.shape)

# Only selecting the columns that i want
df1 = raw_data[['fire_size', 'fire_size_class', 'stat_cause_descr', 'latitude', 'longitude', 'state', 'disc_date_final', 'putout_time' ]]
print(df1.shape)

# Filtering for 'lighting'
df2 = df1[df1['stat_cause_descr'] == 'Lightning' ]
print(df2.shape)
# Out:
# (55367, 43)
# (55367, 8)
# (8218, 8)

# %% [markdown]
# ##### Data Clean

# %%
df2.reset_index()
# Out:
#       index  fire_size fire_size_class stat_cause_descr   latitude  \
# 0        36     1420.0               F        Lightning  33.241800
# 1        40        5.0               B        Lightning  40.834700
# 2        64        1.5               B        Lightning  39.205000
# 3        79        2.5               B        Lightning  42.364444
# 4        84      108.0               D        Lightning  63.851700
# ...     ...        ...             ...              ...        ...
# 8213  55330     9211.0               G        Lightning  44.237000
# 8214  55331     3082.0               F        Lightning  48.383600
# 8215  55332     5200.0               G        Lightning  30.865978
# 8216  55356     4336.0               F        Lightning  34.316000
# 8217  55357     4856.0               F        Lightning  29.616667
#
#        longitude state  disc_date_final                 putout_time
# 0    -104.912200    NM   7/2/1994 10:48   1 days 00:00:00.000000000
# 1    -112.806400    UT  8/14/2006 21:30   1 days 00:00:00.000000000
# 2    -105.188333    CO  7/31/1996 11:45   1 days 00:00:00.000000000
# 3    -112.232222    ID  7/25/2006 13:36   1 days 00:00:00.000000000
# 4    -150.354300    AK   7/1/1997 22:09  26 days 00:00:00.000000000
# ...          ...   ...              ...                         ...
# 8213 -118.992700    OR   8/12/2015 7:08                          85
# 8214 -117.891900    WA  8/14/2015 16:46                         111
# 8215  -94.803980    TX              NaN                         NaN
# 8216 -112.268300    AZ   8/2/2015 12:19                         NaN
# 8217  -94.273333    TX  7/30/2015 16:45                         NaN
#
# [8218 rows x 9 columns]
